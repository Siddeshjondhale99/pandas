# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.5-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.5.1-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.5-cp313-cp313-win_amd64.whl (9.8 MB)
# Using cached numpy-2.5.1-cp313-cp313-win_amd64.whl (12.4 MB)
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...

# %%
import numpy as np
import pandas as pd

# %%
index = ['a','b','c','d']
list = [1,2,3,4]
arr = np.array([5,6,7,8])
dic = {'a':1,'b':2,'c':3,'d':4}

# %%
new = pd.Series(list,index=index)
new
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
maha = pd.Series(arr,index = index)#only accest one d form
maha
# Out:
# a    5
# b    6
# c    7
# d    8
# dtype: int64

# %%
sid=pd.Series(dic)

# %%
sid
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
