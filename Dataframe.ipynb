# %% [markdown]
# How to create the datafram

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
new = pd.DataFrame(data)

# %%
new
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
new_list = pd.DataFrame(data_list)
new_list
column = ["Name","Age","City","Salary"]
new_list = pd.DataFrame(data_list,columns = column)
new_list
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
new_list
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# SELECTION AND INDEXING OF COLUMN

# %%
new_list['Name']
new_list[['Name','Age']]
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# CREATING NEW COLUMN IN TABLE

# %%
new_list['designation'] = ['doc','engg','doc','engg']
new_list
# Out:
#     Name  Age      City  Salary designation
# 0   John   28  New York   65000         doc
# 1   Anna   34     Paris   70000        engg
# 2  Peter   29    Berlin   62000         doc
# 3  Linda   42    London   85000        engg

# %% [markdown]
# DELETING THE COLUMN

# %%
new_list.drop('designation',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_list.drop('designation',axis=1,inplace=True)
#
# NameError: name 'new_list' is not defined

# %%
new_list
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
new_list.drop(0,axis = 0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %%
new_list.loc[1]
# Out:
# Name       Anna
# Age          34
# City      Paris
# Salary    70000
# Name: 1, dtype: object

# %%
new_list.iloc[[2,3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 new_list.iloc[[2,3]]
#
# NameError: name 'new_list' is not defined

# %% [markdown]
# Selecting subset of rows and column

# %%
new_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_list
#
# NameError: name 'new_list' is not defined

# %%
new_list
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
new_list.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
new_list.loc[[2,3],["Name","Salary"]]
# Out:
#     Name  Salary
# 2  Peter   62000
# 3  Linda   85000

# %% [markdown]
# Condition Selection

# %% [markdown]
# condition Selection

# %%
new_list
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
new_list[new_list["Age"] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#and also want who's city is londan
new_list[(new_list["Age"] > 30) & (new_list["City"]=='London')]
# Out:
#     Name  Age    City  Salary
# 3  Linda   42  London   85000
